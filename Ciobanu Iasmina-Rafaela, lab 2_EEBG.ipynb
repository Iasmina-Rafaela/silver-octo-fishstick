# %%
# %%bash
# pwd
# Out:
# /content

# %%
# %%bash
# ls
# Out:
# sample_data

# %%
# %%bash
# ls sample_data
# Out:
# anscombe.json
# california_housing_test.csv
# california_housing_train.csv
# mnist_test.csv
# mnist_train_small.csv
# README.md

# %%
# %%bash
# cd sample_data
# pwd
# Out:
# /content/sample_data

# %%
# %%bash
# echo "Hello World!"
# Out:
# Hello World!

# %%
# %%bash
# echo "wordOne" "wordTwo" "wordThree"
# Out:
# wordOne wordTwo wordThree

# %%
# %%bash
# wget -O example.txt 'https://drive.google.com/uc?export=download&id=1JqblHOsp5LWQ9zBki6Ra0AspQQVOMO9W'
# Out:
# --2024-06-26 09:44:04--  https://drive.google.com/uc?export=download&id=1JqblHOsp5LWQ9zBki6Ra0AspQQVOMO9W
# Resolving drive.google.com (drive.google.com)... 142.251.16.113, 142.251.16.138, 142.251.16.101, ...
# Connecting to drive.google.com (drive.google.com)|142.251.16.113|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1JqblHOsp5LWQ9zBki6Ra0AspQQVOMO9W&export=download [following]
# --2024-06-26 09:44:04--  https://drive.usercontent.google.com/download?id=1JqblHOsp5LWQ9zBki6Ra0AspQQVOMO9W&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.251.16.132, 2607:f8b0:4004:c17::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.251.16.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 146 [application/octet-stream]
# Saving to: ‘example.txt’
#
#      0K                                                       100% 2.68M=0s
#
# 2024-06-26 09:44:05 (2.68 MB/s) - ‘example.txt’ saved [146/146]

# %%
# %%bash
# wget -nv -O example.txt 'https://drive.google.com/uc?export=download&id=1JqblHOsp5LWQ9zBki6Ra0AspQQVOMO9W'
# Out:
# 2024-06-26 09:44:08 URL:https://drive.usercontent.google.com/download?id=1JqblHOsp5LWQ9zBki6Ra0AspQQVOMO9W&export=download [146/146] -> "example.txt" [1]

# %%
# %%bash
# wget -O example.txt 'https://drive.google.com/uc?export=download&id=1JqblHOsp5LWQ9zBki6Ra0AspQQVOMO9W' &>/dev/null

# %%
# %%bash
# cat example.txt
# Out:
# This is an example text file.
# It is used to teach Unix commands.
# For example, the wc, head, and grep commands.
# This file has a total of 4 lines.

# %%
# %%bash
# wget -nv -O exampleTwo.txt 'https://drive.google.com/uc?export=download&id=16jP2qPOn_8ngTjyeRFEWmsv4BePKiQ7h' &>/dev/null
# cat exampleTwo.txt
# Out:
# this is the first line of a second example file
# this file can be concatenated to the first example file
# after concatenation, this line will be the last line

# %%
# %%bash
# cat exampleTwo.txt example.txt
# Out:
# this is the first line of a second example file
# this file can be concatenated to the first example file
# after concatenation, this line will be the last line
# This is an example text file.
# It is used to teach Unix commands.
# For example, the wc, head, and grep commands.
# This file has a total of 4 lines.

# %%
# %%bash
# cat example.txt exampleTwo.txt > combinedExample.txt
# ls
# Out:
# combinedExample.txt
# exampleTwo.txt
# example.txt
# sample_data

# %%
# %%bash
# cat combinedExample.txt
# Out:
# This is an example text file.
# It is used to teach Unix commands.
# For example, the wc, head, and grep commands.
# This file has a total of 4 lines.
# this is the first line of a second example file
# this file can be concatenated to the first example file
# after concatenation, this line will be the last line

# %%
# %%bash
# echo "This string has 1 lines, 12 words, and 70 characters including spaces" | wc
# Out:
#       1      12      70

# %%
# %%bash
# echo "This string has 1 lines, 12 words, and 70 characters including spaces" | wc -l
# Out:
# 1

# %%
# %%bash
# echo "This string has 1 lines, 12 words, and 70 characters including spaces" | wc -w
# Out:
# 12

# %%
# %%bash
# echo "This string has 1 lines, 12 words, and 70 characters including spaces" | wc -m
# Out:
# 70

# %%
# %%bash
# cat combinedExample.txt
# Out:
# This is an example text file.
# It is used to teach Unix commands.
# For example, the wc, head, and grep commands.
# This file has a total of 4 lines.
# this is the first line of a second example file
# this file can be concatenated to the first example file
# after concatenation, this line will be the last line

# %%
# %%bash
# wc combinedExample.txt
# Out:
#   7  58 303 combinedExample.txt

# %%
# %%bash
# cat combinedExample.txt
# Out:
# This is an example text file.
# It is used to teach Unix commands.
# For example, the wc, head, and grep commands.
# This file has a total of 4 lines.
# this is the first line of a second example file
# this file can be concatenated to the first example file
# after concatenation, this line will be the last line

# %%
# %%bash
# grep "this" combinedExample.txt
# Out:
# this is the first line of a second example file
# this file can be concatenated to the first example file
# after concatenation, this line will be the last line

# %%
# %%bash
# grep "This" combinedExample.txt
# Out:
# This is an example text file.
# This file has a total of 4 lines.

# %%
# %%bash
# grep -i "this" combinedExample.txt
# Out:
# This is an example text file.
# This file has a total of 4 lines.
# this is the first line of a second example file
# this file can be concatenated to the first example file
# after concatenation, this line will be the last line

# %%
# %%bash
# grep "^this" combinedExample.txt
# Out:
# this is the first line of a second example file
# this file can be concatenated to the first example file

# %%
# %%bash
# grep "file$" combinedExample.txt
# Out:
# this is the first line of a second example file
# this file can be concatenated to the first example file

# %%
# %%bash
# cat > myScript
# #!/bin/bash
# echo "Hello World!"

# %%
# %%bash
# cat myScript
# Out:
# #!/bin/bash
# echo "Hello World!"

# %%
# %%bash
# ls -l
# Out:
# total 20
# -rw-r--r-- 1 root root  303 Jun 26 09:44 combinedExample.txt
# -rw-r--r-- 1 root root  157 Jan 13  2022 exampleTwo.txt
# -rw-r--r-- 1 root root  146 Jan 13  2022 example.txt
# -rw-r--r-- 1 root root   32 Jun 26 09:44 myScript
# drwxr-xr-x 1 root root 4096 Jun 24 13:28 sample_data

# %%
# %%bash
# chmod u+x myScript

# %%
# %%bash
# ls -l
# Out:
# total 20
# -rw-r--r-- 1 root root  303 Jun 26 09:44 combinedExample.txt
# -rw-r--r-- 1 root root  157 Jan 13  2022 exampleTwo.txt
# -rw-r--r-- 1 root root  146 Jan 13  2022 example.txt
# -rwxr--r-- 1 root root   32 Jun 26 09:44 myScript
# drwxr-xr-x 1 root root 4096 Jun 24 13:28 sample_data

# %%
# %%bash
# ./myScript
# Out:
# Hello World!

# %%
# %%bash
# /content/myScript
# Out:
# Hello World!

# %%
# %%bash
# cat > apprendPractice.txt
# This file has 1 line.

# %%
# %%bash
# cat >> apprendPractice.txt
# This file has 2 lines.

# %%
# %%bash
# cat apprendPractice.txt
# Out:
# This file has 1 line.
# This file has 2 lines.

# %%
# %%bash
# touch example.txt exampleTwo.txt exampleThree.txt

# %%
# %%bash
# for file in *.txt; do
#     echo "Text file found!"
#     echo $file
# done
# Out:
# Text file found!
# apprendPractice.txt
# Text file found!
# combinedExample.txt
# Text file found!
# exampleThree.txt
# Text file found!
# exampleTwo.txt
# Text file found!
# example.txt

# %%
# %%bash
# wget -nv -O IGHJ_Mouse.fa 'https://drive.google.com/uc?export=download&id=19OjK8m9M9WwUZpB-5FLSu7RWeQhRbYKO'
# wget -nv -O IGHJ_Human.fa 'https://drive.google.com/uc?export=download&id=1kUzbiYfBOYQDXUaUzJ4NEGJN9ysPulBz'
# wget -nv -O IGHJ_Zebrafish.fa 'https://drive.google.com/uc?export=download&id=1m0VB08CBfl6GZ9rfCtmDyh6PI7elHcak'
# Out:
# 2024-06-26 09:45:16 URL:https://drive.usercontent.google.com/download?id=19OjK8m9M9WwUZpB-5FLSu7RWeQhRbYKO&export=download [1178/1178] -> "IGHJ_Mouse.fa" [1]
# 2024-06-26 09:45:17 URL:https://drive.usercontent.google.com/download?id=1kUzbiYfBOYQDXUaUzJ4NEGJN9ysPulBz&export=download [2639/2639] -> "IGHJ_Human.fa" [1]
# 2024-06-26 09:45:19 URL:https://drive.usercontent.google.com/download?id=1m0VB08CBfl6GZ9rfCtmDyh6PI7elHcak&export=download [1034/1034] -> "IGHJ_Zebrafish.fa" [1]

# %%
# %%bash
# > headers.txt
#
# for file in *.fa; do
#   grep "^>" "$file" >> headers.txt
# done > headerExtractor

# %%
# %%bash
# > lengths.txt
#
# for file in *.fa; do
#   echo "Processing $file" >> lengths.txt
#
#   grep "^>" "$file" >> lengths.txt
#
#   total_length=$(grep -v "^>" "$file" | tr -d '\n' | wc -c)
#   echo "$total_length" >> lengths.txt
#
#   echo "" >> lengths.txt
# done > seqMeasurer

# %%
# %%bash
# chmod +x headerExtractor
# chmod +x seqMeasurer

# %%
# %%bash
# ./headerExtractor
# ./seqMeasurer
