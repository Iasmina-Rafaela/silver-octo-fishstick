# %%
# %%bash
# pwd
# Out:
# /content

# %%
# %%bash
# ls
# Out:
# sample_data

# %%
# %%bash
# ls sample_data
# Out:
# anscombe.json
# california_housing_test.csv
# california_housing_train.csv
# mnist_test.csv
# mnist_train_small.csv
# README.md

# %%
# %%bash
# cd sample_data
# pwd
# Out:
# /content/sample_data

# %%
# %%bash
# mkdir Repository

# %%
# %%bash
# touch Repository/README

# %%
# %%bash
# mkdir -p Repository/summarydata

# %%
# %%bash
# mkdir -p Repository/notebook

# %%
# %%bash
# mkdir -p  Repository/figure

# %%
# %%bash
# mkdir -p  Repository/multipanel

# %%
# %%bash
# touch Repository/summarydata/README
# touch Repository/summarydata/Figure_1a_data.csv
# touch Repository/summarydata/Figure_1b_data.csv
# touch Repository/summarydata/Figure_2a_data.csv
# touch Repository/summarydata/Figure_2b_data.csv
# touch Repository/summarydata/Figure_2c_data.csv

# %%
# %%bash
# touch Repository/notebook/README
# touch Repository/notebook/Figure1.ipynb
# touch Repository/notebook/Figure2.ipynb

# %%
# %%bash
# touch Repository/figure/README
# touch Repository/figure/Figure1a.pdf
# touch Repository/figure/Figure1b.pdf
# touch Repository/figure/Figure2a.pdf
# touch Repository/figure/Figure2b.pdf
# touch Repository/figure/Figure2c.pdf

# %%
# %%bash
# touch Repository/multipanel/README
# touch Repository/multipanel/Figure1.ai
# touch Repository/multipanel/Figure2.ai
